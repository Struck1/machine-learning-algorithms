# %%
import pandas as pd 
import numpy as np 

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, RobustScaler
from sklearn.model_selection import train_test_split

# %%
# Load dataset
data = r'C:\Users\ASUS\Desktop\data\indian_liver_patient.csv'
df = pd.read_csv(data)
df.columns = df.columns.map(lambda x : x.lower())
#df.columns = df.columns.apply(lambda x : x.lower())
df.head()
# Out:
#    age  gender  total_bilirubin  direct_bilirubin  alkaline_phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    alamine_aminotransferase  aspartate_aminotransferase  total_protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    albumin  albumin_and_globulin_ratio  dataset
# 0      3.3                        0.90        1
# 1      3.2                        0.74        1
# 2      3.3                        0.89        1
# 3      3.4                        1.00        1
# 4      2.4                        0.40        1

# %%
#df.info()
#df.describe(include='all')

# %%
df["albumin_and_globulin_ratio"] = df["albumin_and_globulin_ratio"].fillna(df["albumin_and_globulin_ratio"].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         583 non-null    int64
#  1   gender                      583 non-null    object
#  2   total_bilirubin             583 non-null    float64
#  3   direct_bilirubin            583 non-null    float64
#  4   alkaline_phosphotase        583 non-null    int64
#  5   alamine_aminotransferase    583 non-null    int64
#  6   aspartate_aminotransferase  583 non-null    int64
#  7   total_protiens              583 non-null    float64
#  8   albumin                     583 non-null    float64
#  9   albumin_and_globulin_ratio  583 non-null    float64
#  10  dataset                     583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
#sns.set()
#sns.pairplot(df, kind='reg')

# %%
#sns.set()
#sns.pairplot(df, hue="dataset", kind="reg")

# %%
df.corr()["dataset"]
# Out:
# age                          -0.137351
# total_bilirubin              -0.220208
# direct_bilirubin             -0.246046
# alkaline_phosphotase         -0.184866
# alamine_aminotransferase     -0.163416
# aspartate_aminotransferase   -0.151934
# total_protiens                0.035008
# albumin                       0.161388
# albumin_and_globulin_ratio    0.162319
# dataset                       1.000000
# Name: dataset, dtype: float64

# %%
df.corr().style.background_gradient(cmap="viridis")
# Out:
# <style  type="text/css" >
#     #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row0_col0 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row0_col1 {
#             background-color:  #424186;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row0_col2 {
#             background-color:  #404588;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row0_col3 {
#             background-color:  #3a538b;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row0_col4 {
#             background-color:  #48186a;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row0_col5 {
#             background-color:  #482979;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row0_col6 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row0_col7 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row0_col8 {
#             background-color:  #450559;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row0_col9 {
#             background-color:  #482071;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row1_col0 {
#             background-color:  #3e4989;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row1_col1 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row1_col2 {
#             background-color:  #bddf26;
#             color:  #000000;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row1_col3 {
#             background-color:  #2e6e8e;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row1_col4 {
#             background-color:  #31668e;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row1_col5 {
#             background-color:  #30698e;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row1_col6 {
#             background-color:  #463480;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row1_col7 {
#             background-color:  #470d60;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row1_col8 {
#             background-color:  #46085c;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row1_col9 {
#             background-color:  #46085c;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row2_col0 {
#             background-color:  #3f4889;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row2_col1 {
#             background-color:  #bade28;
#             color:  #000000;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row2_col2 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row2_col3 {
#             background-color:  #2c738e;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row2_col4 {
#             background-color:  #306a8e;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row2_col5 {
#             background-color:  #2e6e8e;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row2_col6 {
#             background-color:  #453781;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row2_col7 {
#             background-color:  #460b5e;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row2_col8 {
#             background-color:  #460b5e;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row2_col9 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row3_col0 {
#             background-color:  #38598c;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row3_col1 {
#             background-color:  #2f6c8e;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row3_col2 {
#             background-color:  #2b748e;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row3_col3 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row3_col4 {
#             background-color:  #3b518b;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row3_col5 {
#             background-color:  #38598c;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row3_col6 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row3_col7 {
#             background-color:  #481d6f;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row3_col8 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row3_col9 {
#             background-color:  #471365;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row4_col0 {
#             background-color:  #46327e;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row4_col1 {
#             background-color:  #2e6e8e;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row4_col2 {
#             background-color:  #2b748e;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row4_col3 {
#             background-color:  #365d8d;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row4_col4 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row4_col5 {
#             background-color:  #86d549;
#             color:  #000000;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row4_col6 {
#             background-color:  #472c7a;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row4_col7 {
#             background-color:  #423f85;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row4_col8 {
#             background-color:  #424086;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row4_col9 {
#             background-color:  #48186a;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row5_col0 {
#             background-color:  #424186;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row5_col1 {
#             background-color:  #2c728e;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row5_col2 {
#             background-color:  #29798e;
#             color:  #000000;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row5_col3 {
#             background-color:  #31668e;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row5_col4 {
#             background-color:  #89d548;
#             color:  #000000;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row5_col5 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row5_col6 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row5_col7 {
#             background-color:  #46327e;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row5_col8 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_21f812b4_ed0d_11ea_b5ed_2c4d543ceac9row5_col9 {
#             background-color:  #481c6e;
#             color:  #f1f1f1;

# %%
df.drop(['direct_bilirubin', 'aspartate_aminotransferase', 'total_protiens', 'albumin'], axis=1, inplace=True)

# %%
df.corr().style.background_gradient(cmap="viridis")
# Out:
# <style  type="text/css" >
#     #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row0_col0 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row0_col1 {
#             background-color:  #424086;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row0_col2 {
#             background-color:  #3a538b;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row0_col3 {
#             background-color:  #48186a;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row0_col4 {
#             background-color:  #450559;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row0_col5 {
#             background-color:  #481a6c;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row1_col0 {
#             background-color:  #423f85;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row1_col1 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row1_col2 {
#             background-color:  #2e6e8e;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row1_col3 {
#             background-color:  #31668e;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row1_col4 {
#             background-color:  #46085c;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row1_col5 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row2_col0 {
#             background-color:  #3c508b;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row2_col1 {
#             background-color:  #2f6c8e;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row2_col2 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row2_col3 {
#             background-color:  #3b518b;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row2_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row2_col5 {
#             background-color:  #460b5e;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row3_col0 {
#             background-color:  #482677;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row3_col1 {
#             background-color:  #2e6e8e;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row3_col2 {
#             background-color:  #365d8d;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row3_col3 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row3_col4 {
#             background-color:  #424086;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row3_col5 {
#             background-color:  #471164;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row4_col0 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row4_col1 {
#             background-color:  #450457;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row4_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row4_col3 {
#             background-color:  #46307e;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row4_col4 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row4_col5 {
#             background-color:  #33638d;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row5_col0 {
#             background-color:  #48186a;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row5_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row5_col2 {
#             background-color:  #471063;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row5_col3 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row5_col4 {
#             background-color:  #32658e;
#             color:  #f1f1f1;
#         }    #T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row5_col5 {
#             background-color:  #fde725;
#             color:  #000000;
#         }</style><table id="T_22254538_ed0d_11ea_8ffe_2c4d543ceac9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >age</th>        <th class="col_heading level0 col1" >total_bilirubin</th>        <th class="col_heading level0 col2" >alkaline_phosphotase</th>        <th class="col_heading level0 col3" >alamine_aminotransferase</th>        <th class="col_heading level0 col4" >albumin_and_globulin_ratio</th>        <th class="col_heading level0 col5" >dataset</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_22254538_ed0d_11ea_8ffe_2c4d543ceac9level0_row0" class="row_heading level0 row0" >age</th>
#                         <td id="T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row0_col1" class="data row0 col1" >0.011763</td>
#                         <td id="T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row0_col2" class="data row0 col2" >0.080425</td>
#                         <td id="T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row0_col3" class="data row0 col3" >-0.086883</td>
#                         <td id="T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row0_col4" class="data row0 col4" >-0.216089</td>
#                         <td id="T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row0_col5" class="data row0 col5" >-0.137351</td>
#             </tr>
#             <tr>
#                         <th id="T_22254538_ed0d_11ea_8ffe_2c4d543ceac9level0_row1" class="row_heading level0 row1" >total_bilirubin</th>
#                         <td id="T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row1_col0" class="data row1 col0" >0.011763</td>
#                         <td id="T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row1_col2" class="data row1 col2" >0.206669</td>
#                         <td id="T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row1_col3" class="data row1 col3" >0.214065</td>
#                         <td id="T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row1_col4" class="data row1 col4" >-0.206159</td>
#                         <td id="T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row1_col5" class="data row1 col5" >-0.220208</td>
#             </tr>
#             <tr>
#                         <th id="T_22254538_ed0d_11ea_8ffe_2c4d543ceac9level0_row2" class="row_heading level0 row2" >alkaline_phosphotase</th>
#                         <td id="T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row2_col0" class="data row2 col0" >0.080425</td>
#                         <td id="T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row2_col1" class="data row2 col1" >0.206669</td>
#                         <td id="T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row2_col3" class="data row2 col3" >0.125680</td>
#                         <td id="T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row2_col4" class="data row2 col4" >-0.233960</td>
#                         <td id="T_22254538_ed0d_11ea_8ffe_2c4d543ceac9row2_col5" class="data row2 col5" >-0.184866</td>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         583 non-null    int64
#  1   gender                      583 non-null    object
#  2   total_bilirubin             583 non-null    float64
#  3   alkaline_phosphotase        583 non-null    int64
#  4   alamine_aminotransferase    583 non-null    int64
#  5   albumin_and_globulin_ratio  583 non-null    float64
#  6   dataset                     583 non-null    int64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 32.0+ KB

# %%
# outlier check
plt.figure(figsize=(15,20))

for i, c in enumerate(df.drop("dataset", axis=1).select_dtypes(include="number").columns):
    plt.subplot(10, 2, i*2 +1)
    sns.boxplot(df[c], color="blue")
    plt.title("Distribution :" + c)
    plt.xlabel('')
    plt.tight_layout(pad=0.4)

    plt.subplot(10, 2, i*2 +2)
    sns.boxplot(df[c].apply('log1p'), color="red")
    plt.xlabel('')
    plt.title('Log1p distribution:' + c)

# %%
plt.figure(figsize=(15,20))

for i, c in enumerate(df.select_dtypes(include="number").columns):
    plt.subplot(5, 2, i+1)
    sns.distplot(df[c])
    plt.title("Distribution :" + c)
    plt.xlabel("")
    plt.tight_layout(pad=0.4)

# %%
# Strongly skewed features :  total_bilirubin, alkaline_phosphotase, alamine_aminotransferase, albumin_and_globulin_ratio
# Save skewed features
skewed_col = df[["total_bilirubin", "alkaline_phosphotase", "alamine_aminotransferase", "albumin_and_globulin_ratio"]]

# %%
# Apply log1p transformation just selected columns
for c in skewed_col:
    df[c] = df[c].apply("log1p")

# %%
plt.figure(figsize=(15,20))

for i, c in enumerate(df.select_dtypes(include="number").columns):
    plt.subplot(5, 2, i+1)
    sns.distplot(df[c].apply("log1p"))
    plt.title("Distribution :" + c)
    plt.xlabel("")
    plt.tight_layout(pad=0.4)

# %%
df.head()
# Out:
#    age  gender  total_bilirubin  alkaline_phosphotase  \
# 0   65  Female         0.530628              5.236442
# 1   62    Male         2.476538              6.551080
# 2   62    Male         2.116256              6.196444
# 3   58    Male         0.693147              5.209486
# 4   72    Male         1.589235              5.278115
#
#    alamine_aminotransferase  albumin_and_globulin_ratio  dataset
# 0                  2.833213                    0.641854        1
# 1                  4.174387                    0.553885        1
# 2                  4.110874                    0.636577        1
# 3                  2.708050                    0.693147        1
# 4                  3.332205                    0.336472        1

# %%
# Scale
le = LabelEncoder()
df["gender"] = le.fit_transform(df["gender"])
df["gender"].head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# Name: gender, dtype: int32

# %%
rs = RobustScaler()
for i in df.iloc[:, :-1].columns:
    df[i] = rs.fit_transform(df[i].values.reshape(-1,1))
df.head()
# Out:
#     age  gender  total_bilirubin  alkaline_phosphotase  \
# 0  0.80    -1.0        -0.234465             -0.200886
# 1  0.68     0.0         2.572890              2.293084
# 2  0.68     0.0         2.053111              1.620312
# 3  0.52     0.0         0.000000             -0.252023
# 4  1.08     0.0         1.292782             -0.121830
#
#    alamine_aminotransferase  albumin_and_globulin_ratio  dataset
# 0                 -0.797391                   -0.115796        1
# 1                  0.627949                   -0.532099        1
# 2                  0.560449                   -0.140769        1
# 3                 -0.930409                    0.126945        1
# 4                 -0.267086                   -1.560985        1

# %%
df.to_csv("data.csv", index=False)

clean_data = pd.read_csv("data.csv")
clean_data.head()
# Out:
#     age  gender  total_bilirubin  alkaline_phosphotase  \
# 0  0.80    -1.0        -0.234465             -0.200886
# 1  0.68     0.0         2.572890              2.293084
# 2  0.68     0.0         2.053111              1.620312
# 3  0.52     0.0         0.000000             -0.252023
# 4  1.08     0.0         1.292782             -0.121830
#
#    alamine_aminotransferase  albumin_and_globulin_ratio  dataset
# 0                 -0.797391                   -0.115796        1
# 1                  0.627949                   -0.532099        1
# 2                  0.560449                   -0.140769        1
# 3                 -0.930409                    0.126945        1
# 4                 -0.267086                   -1.560985        1
